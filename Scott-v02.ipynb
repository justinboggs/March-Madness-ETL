# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
import json
from time import sleep
from datetime import date
from sqlalchemy import create_engine
import os

# Output File location
output_folder = "output_data"

# Import local postgres username and password
from config import username, password

# %%
# Load data - Big Dance
rawdf_BigDance = pd.read_csv('Big_Dance_CSV.csv', low_memory=False)
rawdf_cbb = pd.read_csv('cbb.csv', low_memory=False)
rawdf_cbb15 = pd.read_csv('cbb15.csv', low_memory=False)
rawdf_cbb16 = pd.read_csv('cbb16.csv', low_memory=False)
rawdf_cbb17 = pd.read_csv('cbb17.csv', low_memory=False)
rawdf_cbb18 = pd.read_csv('cbb18.csv', low_memory=False)
rawdf_cbb19 = pd.read_csv('cbb19.csv', low_memory=False)

# %% [markdown]
# # EDA - Big Dance

# %%
rows_in_df = len(rawdf_BigDance)
print(f'Big Dance set has {rows_in_df} rows')
rawdf_BigDance.head(5)
# Out:
# Big Dance set has 2205 rows
#    Year  Round  Region Number Region Name  Seed  Score        Team  \
# 0  1985      1              1        West     1     83    St Johns
# 1  1985      1              1        West     2     81         VCU
# 2  1985      1              1        West     3     65    NC State
# 3  1985      1              1        West     4     85        UNLV
# 4  1985      1              1        West     5     58  Washington
#
#          Team.1  Score.1  Seed.1
# 0      Southern       59      16
# 1      Marshall       65      15
# 2        Nevada       56      14
# 3  San Diego St       80      13
# 4      Kentucky       65      12

# %%
rawdf_BigDance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 10 columns):
# Year             2205 non-null int64
# Round            2205 non-null int64
# Region Number    2205 non-null int64
# Region Name      2205 non-null object
# Seed             2205 non-null int64
# Score            2205 non-null int64
# Team             2205 non-null object
# Team.1           2205 non-null object
# Score.1          2205 non-null int64
# Seed.1           2205 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 172.4+ KB

# %%
rawdf_BigDance.describe()
# Out:
#               Year        Round  Region Number         Seed        Score  \
# count  2205.000000  2205.000000    2205.000000  2205.000000  2205.000000
# mean   2002.000000     1.904762       2.444444     3.887528    74.304308
# std      10.101796     1.191698       1.123993     2.900662    12.753399
# min    1985.000000     1.000000       1.000000     1.000000    32.000000
# 25%    1993.000000     1.000000       1.000000     2.000000    65.000000
# 50%    2002.000000     1.000000       2.000000     3.000000    74.000000
# 75%    2011.000000     2.000000       3.000000     6.000000    82.000000
# max    2019.000000     6.000000       4.000000    16.000000   131.000000
#
#            Score.1       Seed.1
# count  2205.000000  2205.000000
# mean     68.051701     9.474830
# std      12.295443     4.138256
# min      29.000000     1.000000
# 25%      59.000000     6.000000
# 50%      67.000000    10.000000
# 75%      76.000000    13.000000
# max     149.000000    16.000000

# %%
# Only 2015+ data
df_bigdance = rawdf_BigDance[rawdf_BigDance["Year"] >= 2015]
df_bigdance.columns
# Out:
# Index(['Year', 'Round', 'Region Number', 'Region Name', 'Seed', 'Score',
#        'Team', 'Team.1', 'Score.1', 'Seed.1'],
#       dtype='object')

# %%
df_bigdance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315 entries, 1890 to 2204
# Data columns (total 10 columns):
# Year             315 non-null int64
# Round            315 non-null int64
# Region Number    315 non-null int64
# Region Name      315 non-null object
# Seed             315 non-null int64
# Score            315 non-null int64
# Team             315 non-null object
# Team.1           315 non-null object
# Score.1          315 non-null int64
# Seed.1           315 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 27.1+ KB

# %%
df_bigdance = df_bigdance.rename(columns={
    "Seed":    "Home_Seed"
    , "Score":   "Home_Score"
    , "Team":    "Home_Team" 
    , "Team.1":  "Away_Team" 
    , "Score.1": "Away_Score"
    , "Seed.1":   "Away_Seed" 
})

# %%
df_bigdance.head()
# Out:
#       Year  Round  Region Number Region Name  Home_Seed  Home_Score  \
# 1890  2015      1              1     Midwest          1          79
# 1891  2015      1              1     Midwest          2          75
# 1892  2015      1              1     Midwest          3          69
# 1893  2015      1              1     Midwest          4          65
# 1894  2015      1              1     Midwest          5          68
#
#           Home_Team      Away_Team  Away_Score  Away_Seed
# 1890       Kentucky        Hampton          56         16
# 1891         Kansas  New Mexico St          56         15
# 1892     Notre Dame   Northeastern          65         14
# 1893       Maryland     Valparaiso          62         13
# 1894  West Virginia        Buffalo          62         12

# %% [markdown]
# # EDA - Conference data

# %%
rows_in_df = len(rawdf_cbb)
print(f'CBB data set has {rows_in_df} rows')
rawdf_cbb.head(5)
# Out:
# CBB data set has 1757 rows
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3      Texas Tech  B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4         Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3  ...  36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4  ...  26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
#
# [5 rows x 24 columns]

# %%
rawdf_cbb.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000
# mean     31.523051    16.513375   103.542402   103.542459     0.493398
# std       2.602819     6.545571     7.304975     6.472676     0.255291
# min      24.000000     0.000000    76.700000    84.000000     0.007700
# 25%      30.000000    12.000000    98.600000    98.900000     0.283700
# 50%      31.000000    16.000000   103.100000   103.800000     0.474000
# 75%      33.000000    21.000000   108.100000   108.000000     0.710600
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000  ...
# mean     50.120489    50.312806    18.591804    18.521286    29.277120  ...
# std       3.130430     2.859604     1.991637     2.108968     4.101782  ...
# min      39.400000    39.600000    12.400000    10.200000    15.000000  ...
# 25%      48.100000    48.400000    17.200000    17.100000    26.600000  ...
# 50%      50.000000    50.300000    18.500000    18.500000    29.400000  ...
# 75%      52.100000    52.300000    19.800000    19.900000    31.900000  ...
# max      59.800000    59.500000    26.100000    28.000000    42.100000  ...
#
#                FTR         FTRD         2P_O         2P_D         3P_O  \
# count  1757.000000  1757.000000  1757.000000  1757.000000  1757.000000
# mean     35.097894    35.373307    49.135970    49.298065    34.563517
# std       4.884599     5.900935     3.422136     3.288265     2.742323
# min      21.600000    21.800000    37.700000    37.700000    25.200000
# 25%      31.700000    31.200000    46.900000    47.100000    32.600000
# 50%      34.900000    34.900000    49.000000    49.300000    34.600000
# 75%      38.300000    39.200000    51.400000    51.500000    36.400000
# max      51.000000    58.500000    62.600000    61.200000    44.100000
#
#               3P_D        ADJ_T          WAB        SEED         YEAR
# count  1757.000000  1757.000000  1757.000000  340.000000  1757.000000
# mean     34.744792    68.422254    -7.837109    8.791176  2017.002277
# std       2.369727     3.258920     6.988694    4.674090     1.415419
# min      27.100000    57.200000   -25.200000    1.000000  2015.000000
# 25%      33.100000    66.400000   -13.000000    5.000000  2016.000000
# 50%      34.700000    68.500000    -8.400000    9.000000  2017.000000
# 75%      36.300000    70.400000    -3.100000   13.000000  2018.000000
# max      43.100000    83.400000    13.100000   16.000000  2019.000000
#
# [8 rows x 21 columns]

# %%
rawdf_cbb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757 entries, 0 to 1756
# Data columns (total 24 columns):
# TEAM          1757 non-null object
# CONF          1757 non-null object
# G             1757 non-null int64
# W             1757 non-null int64
# ADJOE         1757 non-null float64
# ADJDE         1757 non-null float64
# BARTHAG       1757 non-null float64
# EFG_O         1757 non-null float64
# EFG_D         1757 non-null float64
# TOR           1757 non-null float64
# TORD          1757 non-null float64
# ORB           1757 non-null float64
# DRB           1757 non-null float64
# FTR           1757 non-null float64
# FTRD          1757 non-null float64
# 2P_O          1757 non-null float64
# 2P_D          1757 non-null float64
# 3P_O          1757 non-null float64
# 3P_D          1757 non-null float64
# ADJ_T         1757 non-null float64
# WAB           1757 non-null float64
# POSTSEASON    340 non-null object
# SEED          340 non-null float64
# YEAR          1757 non-null int64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 329.6+ KB

# %% [markdown]
# # Load into database

# %%
# rds_connection_string = "postgres:postgres@localhost:5432/GroupDb"
#rds_connection_string = "Jupyter:password1@localhost:60000/Day2"
#engine = create_engine(f'postgresql://{rds_connection_string}')
# engine.table_names()

# Create connection to local postgres 'sql_challenge' database
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Day2')

# %%
df_bigdance.to_sql(name='BigDance', con=engine, if_exists='append', index=False)
rawdf_cbb.to_sql(name='Conference', con=engine, if_exists='append', index=False)

# %%
# "E" phase finished - # Go do "TL" in SQL!

# %% [markdown]
# # Post ETL - Load the CSV into Pandas

# %%
df = pd.read_csv('FinalData.csv', low_memory=False)

# %%
df.head()

# %% [markdown]
# # Read Final Data View

# %%
from sqlalchemy import inspect

# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
# Collect the names of tables within the database
inspector.get_table_names()
# Out:
# ['BigDance',
#  'Conference',
#  'lastfiveyears',
#  'bigdanceteams',
#  'finalteamconference']

# %%
# Collect the names of views within the database
inspector.get_view_names()
# Out:
# ['finaldata']

# %%
# Using the inspector to print the column names within the selected table and its types
columns = inspector.get_columns('finaldata')
for column in columns:
    print(column["name"], column["type"])
# Out:
# Year BIGINT
# Round BIGINT
# Region Number BIGINT
# Region Name TEXT
# Home_Seed BIGINT
# Home_Score BIGINT
# Home_Team TEXT
# Away_Team TEXT
# Away_Score BIGINT
# Away_Seed BIGINT
# Home_Conference TEXT
# Away_Conference TEXT

# %% [markdown]
# ### Note:  Remove spaces from column names; 'Region Number', 'Region Name'

# %%
# Query finaldata.  Return all rows
engine.execute("SELECT * FROM finaldata").fetchall()
# Out:
# [(2015, 1, 1, 'Midwest', 2, 75, 'Kansas', 'New Mexico St', 56, 15, 'B12', 'WAC'),
#  (2015, 1, 1, 'Midwest', 3, 69, 'Notre Dame', 'Northeastern', 65, 14, 'ACC', 'CAA'),
#  (2015, 1, 1, 'Midwest', 5, 68, 'West Virginia', 'Buffalo', 62, 12, 'B12', 'MAC'),
#  (2015, 1, 1, 'Midwest', 6, 56, 'Butler', 'Texas', 48, 11, 'BE', 'B12'),
#  (2015, 1, 1, 'Midwest', 8, 66, 'Cincinnati', 'Purdue', 65, 9, 'Amer', 'B10'),
#  (2015, 1, 2, 'West', 2, 93, 'Arizona', 'Texas Southern', 72, 15, 'P12', 'SWAC'),
#  (2015, 1, 2, 'West', 3, 56, 'Baylor', 'Georgia St', 57, 14, 'B12', 'SB'),
#  (2015, 1, 2, 'West', 4, 67, 'North Carolina', 'Harvard', 65, 13, 'ACC', 'Ivy'),
#  (2015, 1, 2, 'West', 5, 56, 'Arkansas', 'Wofford', 53, 12, 'SEC', 'SC'),
#  (2015, 1, 2, 'West', 6, 76, 'Xavier', 'Ole Miss', 57, 11, 'BE', 'SEC'),
#  (2015, 1, 2, 'West', 7, 72, 'VCU', 'Ohio St', 75, 10, 'A10', 'B10'),
#  (2015, 1, 2, 'West', 8, 79, 'Oregon', 'Oklahoma St', 73, 9, 'P12', 'B12'),
#  (2015, 1, 3, 'East', 1, 93, 'Villanova', 'Lafayette', 52, 16, 'BE', 'Pat'),
#  (2015, 1, 3, 'East', 2, 79, 'Virginia', 'Belmont', 67, 15, 'ACC', 'OVC'),
#  (2015, 1, 3, 'East', 3, 69, 'Oklahoma', 'Albany', 60, 14, 'B12', 'AE'),
#  (2015, 1, 3, 'East', 5, 71, 'Northern Iowa', 'Wyoming', 54, 12, 'MVC', 'MWC'),
#  (2015, 1, 3, 'East', 6, 53, 'Providence', 'Dayton', 66, 11, 'BE', 'A10'),
#  (2015, 1, 3, 'East', 7, 70, 'Michigan St', 'Georgia', 63, 10, 'B10', 'SEC'),
#  (2015, 1, 3, 'East', 8, 66, 'NC State', 'LSU', 65, 9, 'ACC', 'SEC'),
#  (2015, 1, 4, 'South', 1, 85, 'Duke', 'Robert Morris', 56, 16, 'ACC', 'NEC'),
#  (2015, 1, 4, 'South', 2, 86, 'Gonzaga', 'North Dakota St', 76, 15, 'WCC', 'Sum'),
#  (2015, 1, 4, 'South', 3, 59, 'Iowa St', 'UAB', 60, 14, 'B12', 'CUSA'),
#  (2015, 1, 4, 'South', 4, 84, 'Georgetown', 'Eastern Washington', 74, 13, 'BE', 'BSky'),
#  (2016, 3, 2, 'West', 2, 77, 'Oklahoma', 'Texas A&M', 63, 3, 'B12', 'SEC'),
#  (2016, 3, 3, 'East', 1, 101, 'North Carolina', 'Indiana', 86, 5, 'ACC', 'B10'),
#  (2016, 3, 3, 'East', 7, 56, 'Wisconsin', 'Notre Dame', 61, 6, 'B10', 'ACC'),
#  (2016, 3, 4, 'Midwest', 1, 84, 'Virginia', 'Iowa St', 71, 4, 'ACC', 'B12'),
#  (2016, 3, 4, 'Midwest', 10, 63, 'Syracuse', 'Gonzaga', 60, 11, 'ACC', 'WCC'),
#  (2016, 4, 1, 'South', 1, 59, 'Kansas', 'Villanova', 64, 2, 'B12', 'BE'),
#  (2016, 4, 2, 'West', 1, 68, 'Oregon', 'Oklahoma', 80, 2, 'P12', 'B12'),
#  (2016, 4, 3, 'East', 1, 88, 'North Carolina', 'Notre Dame', 74, 6, 'ACC', 'ACC'),
#  (2016, 4, 4, 'Midwest', 1, 62, 'Virginia', 'Syracuse', 68, 10, 'ACC', 'ACC'),
#  (2016, 5, 1, 'Final Four', 2, 95, 'Villanova', 'Oklahoma', 51, 2, 'BE', 'B12'),
#  (2016, 5, 2, 'Final Four', 1, 83, 'North Carolina', 'Syracuse', 66, 10, 'ACC', 'ACC'),
#  (2016, 6, 1, 'Championship', 2, 77, 'Villanova', 'North Carolina', 74, 1, 'BE', 'ACC'),
#  (2017, 1, 1, 'East', 1, 76, 'Villanova', 'Mount St Marys', 56, 16, 'BE', 'NEC'),
#  (2017, 1, 1, 'East', 2, 87, 'Duke', 'Troy', 65, 15, 'ACC', 'SB'),
#  (2017, 1, 1, 'East', 3, 91, 'Baylor', 'New Mexico St', 73, 14, 'B12', 'WAC'),
#  (2017, 1, 1, 'East', 4, 80, 'Florida', 'East Tennessee St', 65, 13, 'SEC', 'SC'),
#  (2017, 1, 1, 'East', 5, 76, 'Virginia', 'UNC Wilmington', 71, 12, 'ACC', 'CAA'),
#  (2017, 1, 1, 'East', 6, 65, 'SMU', 'USC', 66, 11, 'Amer', 'P12'),
#  (2017, 1, 1, 'East', 7, 93, 'South Carolina', 'Marquette', 73, 10, 'SEC', 'BE'),
#  (2017, 1, 1, 'East', 8, 84, 'Wisconsin', 'Virginia Tech', 74, 9, 'B10', 'ACC'),
#  (2017, 1, 2, 'West', 1, 66, 'Gonzaga', 'South Dakota St', 46, 16, 'WCC', 'Sum'),
#  (2017, 1, 2, 'West', 2, 100, 'Arizona', 'North Dakota', 82, 15, 'P12', 'BSky'),
#  (2017, 1, 2, 'West', 3, 86, 'Florida St', 'Florida Gulf Coast', 80, 14, 'ACC', 'ASun'),
#  (2017, 1, 2, 'West', 4, 86, 'West Virginia', 'Bucknell', 80, 13, 'B12', 'Pat'),
#  (2017, 1, 2, 'West', 5, 60, 'Notre Dame', 'Princeton', 58, 12, 'ACC', 'Ivy'),
#  (2017, 1, 2, 'West', 6, 65, 'Maryland', 'Xavier', 76, 11, 'B10', 'BE'),
#  (2017, 1, 2, 'West', 7, 85, 'St Marys', 'VCU', 77, 10, 'WCC', 'A10'),
#  (2017, 1, 2, 'West', 8, 68, 'Northwestern', 'Vanderbilt', 66, 9, 'B10', 'SEC'),
#  (2017, 1, 3, 'Midwest', 1, 100, 'Kansas', 'UC Davis', 62, 16, 'B12', 'BW'),
#  (2017, 1, 3, 'Midwest', 2, 78, 'Louisville', 'Jacksonville St', 63, 15, 'ACC', 'OVC'),
#  (2017, 1, 3, 'Midwest', 3, 93, 'Oregon', 'Iona', 77, 14, 'P12', 'MAAC'),
#  (2017, 1, 3, 'Midwest', 4, 80, 'Purdue', 'Vermont', 70, 13, 'B10', 'AE'),
#  (2017, 1, 3, 'Midwest', 5, 84, 'Iowa St', 'Nevada', 73, 12, 'B12', 'MWC'),
#  (2017, 1, 3, 'Midwest', 6, 72, 'Creighton', 'Rhode Island', 84, 11, 'BE', 'A10'),
#  (2017, 1, 3, 'Midwest', 7, 92, 'Michigan', 'Oklahoma St', 91, 10, 'B10', 'B12'),
#  (2017, 1, 3, 'Midwest', 8, 58, 'Miami', 'Michigan St', 78, 9, 'ACC', 'B10'),
#  (2017, 1, 4, 'South', 1, 103, 'North Carolina', 'Texas Southern', 64, 16, 'ACC', 'SWAC'),
#  (2017, 1, 4, 'South', 3, 97, 'UCLA', 'Kent St', 80, 14, 'P12', 'MAC'),
#  (2017, 1, 4, 'South', 4, 76, 'Butler', 'Winthrop', 64, 13, 'BE', 'BSth'),
#  (2017, 1, 4, 'South', 5, 72, 'Minnesota', 'Middle Tennessee St', 81, 12, 'B10', 'CUSA'),
#  (2017, 1, 4, 'South', 6, 75, 'Cincinnati', 'Kansas St', 61, 11, 'Amer', 'B12'),
#  (2017, 1, 4, 'South', 8, 77, 'Arkansas', 'Seton Hall', 71, 9, 'SEC', 'BE'),
#  (2017, 2, 1, 'East', 1, 62, 'Villanova', 'Wisconsin', 65, 8, 'BE', 'B10'),
#  (2017, 2, 1, 'East', 2, 81, 'Duke', 'South Carolina', 88, 7, 'ACC', 'SEC'),
#  (2017, 2, 1, 'East', 3, 82, 'Baylor', 'USC', 78, 11, 'B12', 'P12'),
#  (2017, 2, 1, 'East', 4, 65, 'Florida', 'Virginia', 39, 5, 'SEC', 'ACC'),
#  (2017, 2, 2, 'West', 1, 79, 'Gonzaga', 'Northwestern', 73, 8, 'WCC', 'B10'),
#  (2017, 2, 2, 'West', 2, 69, 'Arizona', 'St Marys', 60, 7, 'P12', 'WCC'),
#  (2017, 2, 2, 'West', 3, 66, 'Florida St', 'Xavier', 91, 11, 'ACC', 'BE'),
#  (2017, 2, 2, 'West', 4, 83, 'West Virginia', 'Notre Dame', 71, 5, 'B12', 'ACC'),
#  (2017, 2, 3, 'Midwest', 1, 90, 'Kansas', 'Michigan St', 70, 9, 'B12', 'B10'),
#  (2017, 2, 3, 'Midwest', 2, 69, 'Louisville', 'Michigan', 73, 7, 'ACC', 'B10'),
#  (2017, 2, 3, 'Midwest', 3, 75, 'Oregon', 'Rhode Island', 72, 11, 'P12', 'A10'),
#  (2017, 2, 3, 'Midwest', 4, 80, 'Purdue', 'Iowa St', 76, 5, 'B10', 'B12'),
#  (2018, 1, 2, 'West', 2, 84, 'North Carolina', 'Lipscomb', 66, 15, 'ACC', 'ASun'),
#  (2018, 1, 2, 'West', 3, 61, 'Michigan', 'Montana', 47, 14, 'B10', 'BSky'),
#  (2018, 1, 2, 'West', 4, 68, 'Gonzaga', 'UNC Greensboro', 64, 13, 'WCC', 'SC'),
#  (2018, 1, 2, 'West', 5, 81, 'Ohio St', 'South Dakota St', 73, 12, 'B10', 'Sum'),
#  (2018, 1, 2, 'West', 6, 67, 'Houston', 'San Diego St', 65, 11, 'Amer', 'MWC'),
#  (2018, 1, 2, 'West', 7, 73, 'Texas A&M', 'Providence', 69, 10, 'SEC', 'BE'),
#  (2018, 1, 2, 'West', 8, 54, 'Missouri', 'Florida St', 67, 9, 'SEC', 'ACC'),
#  (2018, 1, 3, 'East', 1, 87, 'Villanova', 'Radford', 61, 16, 'BE', 'BSth'),
#  (2018, 1, 3, 'East', 2, 74, 'Purdue', 'Cal St Fullerton', 48, 15, 'B10', 'BW'),
#  (2018, 1, 3, 'East', 3, 70, 'Texas Tech', 'Stephen F Austin', 60, 14, 'B12', 'Slnd'),
#  (2018, 1, 3, 'East', 5, 85, 'West Virginia', 'Murray St', 68, 12, 'B12', 'OVC'),
#  (2018, 1, 3, 'East', 6, 77, 'Florida', 'St Bonaventure', 62, 11, 'SEC', 'A10'),
#  (2018, 1, 3, 'East', 7, 62, 'Arkansas', 'Butler', 79, 10, 'SEC', 'BE'),
#  (2018, 1, 3, 'East', 8, 83, 'Virginia Tech', 'Alabama', 86, 9, 'ACC', 'SEC'),
#  (2018, 1, 4, 'Midwest', 1, 76, 'Kansas', 'Pennsylvania', 60, 16, 'B12', 'Ivy'),
#  (2018, 1, 4, 'Midwest', 2, 89, 'Duke', 'Iona', 67, 15, 'ACC', 'MAAC'),
#  (2018, 1, 4, 'Midwest', 3, 82, 'Michigan St', 'Bucknell', 78, 14, 'B10', 'Pat'),
#  (2018, 1, 4, 'Midwest', 4, 62, 'Auburn', 'College of Charleston', 58, 13, 'SEC', 'CAA'),
#  (2018, 1, 4, 'Midwest', 5, 79, 'Clemson', 'New Mexico St', 68, 12, 'ACC', 'WAC'),
#  (2018, 1, 4, 'Midwest', 6, 52, 'TCU', 'Syracuse', 57, 11, 'B12', 'ACC'),
#  (2018, 1, 4, 'Midwest', 7, 83, 'Rhode Island', 'Oklahoma', 78, 10, 'A10', 'B12'),
#  (2018, 1, 4, 'Midwest', 8, 94, 'Seton Hall', 'NC State', 83, 9, 'BE', 'ACC'),
#  (2018, 2, 1, 'South', 16, 43, 'UMBC', 'Kansas St', 50, 9, 'AE', 'B12'),
#  (2018, 2, 1, 'South', 2, 73, 'Cincinnati', 'Nevada', 75, 7, 'Amer', 'MWC'),
#  (2018, 2, 1, 'South', 3, 62, 'Tennessee', 'Loyola Chicago', 63, 11, 'SEC', 'MVC'),
#  (2018, 2, 1, 'South', 13, 75, 'Buffalo', 'Kentucky', 95, 5, 'MAC', 'SEC'),
#  (2018, 2, 2, 'West', 1, 70, 'Xavier', 'Florida St', 75, 9, 'BE', 'ACC'),
#  (2018, 2, 2, 'West', 2, 65, 'North Carolina', 'Texas A&M', 86, 7, 'ACC', 'SEC'),
#  (2018, 2, 2, 'West', 3, 64, 'Michigan', 'Houston', 63, 6, 'B10', 'Amer'),
#  (2018, 2, 2, 'West', 4, 90, 'Gonzaga', 'Ohio St', 84, 5, 'WCC', 'B10'),
#  (2018, 2, 3, 'East', 1, 81, 'Villanova', 'Alabama', 58, 9, 'BE', 'SEC'),
#  (2018, 2, 3, 'East', 2, 76, 'Purdue', 'Butler', 73, 10, 'B10', 'BE'),
#  (2018, 2, 3, 'East', 3, 69, 'Texas Tech', 'Florida', 66, 6, 'B12', 'SEC'),
#  (2018, 2, 3, 'East', 13, 71, 'Marshall', 'West Virginia', 94, 5, 'CUSA', 'B12'),
#  (2018, 2, 4, 'Midwest', 1, 83, 'Kansas', 'Seton Hall', 79, 8, 'B12', 'BE'),
#  (2018, 2, 4, 'Midwest', 2, 87, 'Duke', 'Rhode Island', 62, 7, 'ACC', 'A10'),
#  (2018, 2, 4, 'Midwest', 3, 53, 'Michigan St', 'Syracuse', 55, 11, 'B10', 'ACC'),
#  (2018, 2, 4, 'Midwest', 4, 53, 'Auburn', 'Clemson', 84, 5, 'SEC', 'ACC'),
#  (2018, 3, 1, 'South', 9, 61, 'Kansas St', 'Kentucky', 58, 5, 'B12', 'SEC'),
#  (2018, 3, 1, 'South', 7, 68, 'Nevada', 'Loyola Chicago', 69, 11, 'MWC', 'MVC'),
#  (2018, 3, 2, 'West', 9, 75, 'Florida St', 'Gonzaga', 60, 4, 'ACC', 'WCC'),
#  (2018, 3, 2, 'West', 7, 72, 'Texas A&M', 'Michigan', 99, 3, 'SEC', 'B10'),
#  (2018, 3, 3, 'East', 1, 90, 'Villanova', 'West Virginia', 78, 5, 'BE', 'B12'),
#  (2018, 3, 3, 'East', 2, 65, 'Purdue', 'Texas Tech', 78, 3, 'B10', 'B12'),
#  (2018, 3, 4, 'Midwest', 1, 80, 'Kansas', 'Clemson', 76, 5, 'B12', 'ACC'),
#  (2018, 3, 4, 'Midwest', 2, 69, 'Duke', 'Syracuse', 65, 11, 'ACC', 'ACC'),
#  (2018, 4, 1, 'South', 9, 62, 'Kansas St', 'Loyola Chicago', 78, 11, 'B12', 'MVC'),
#  (2018, 4, 2, 'West', 9, 54, 'Florida St', 'Michigan', 58, 3, 'ACC', 'B10'),
#  (2018, 4, 3, 'East', 1, 71, 'Villanova', 'Texas Tech', 59, 3, 'BE', 'B12'),
#  (2018, 4, 4, 'Midwest', 1, 85, 'Kansas', 'Duke', 81, 2, 'B12', 'ACC'),
#  (2018, 5, 1, 'Final Four', 11, 57, 'Loyola Chicago', 'Michigan', 69, 3, 'MVC', 'B10'),
#  (2018, 5, 2, 'Final Four', 1, 95, 'Villanova', 'Kansas', 79, 1, 'BE', 'B12'),
#  (2018, 6, 1, 'Championship', 3, 62, 'Michigan', 'Villanova', 79, 1, 'B10', 'BE'),
#  (2019, 1, 1, 'East', 1, 85, 'Duke', 'North Dakota St', 62, 16, 'ACC', 'Sum'),
#  (2019, 1, 1, 'East', 2, 76, 'Michigan St', 'Bradley', 65, 15, 'B10', 'MVC'),
#  (2019, 1, 1, 'East', 3, 79, 'LSU', 'Yale', 74, 14, 'SEC', 'Ivy'),
#  (2019, 1, 1, 'East', 4, 66, 'Virginia Tech', 'St Louis', 52, 13, 'ACC', 'A10'),
#  (2019, 1, 1, 'East', 5, 76, 'Mississippi St', 'Liberty', 80, 12, 'SEC', 'BSth'),
#  (2019, 1, 1, 'East', 6, 79, 'Maryland', 'Belmont', 77, 11, 'B10', 'OVC'),
#  (2019, 1, 1, 'East', 7, 76, 'Louisville', 'Minnesota', 86, 10, 'ACC', 'B10'),
#  (2019, 1, 1, 'East', 8, 58, 'VCU', 'Central Florida', 73, 9, 'A10', 'Amer'),
#  (2019, 1, 2, 'West', 1, 87, 'Gonzaga', 'Fairleigh Dickinson', 49, 16, 'WCC', 'NEC'),
#  (2019, 1, 2, 'West', 2, 74, 'Michigan', 'Montana', 55, 15, 'B10', 'BSky'),
#  (2019, 1, 2, 'West', 4, 76, 'Florida St', 'Vermont', 69, 13, 'ACC', 'AE'),
#  (2019, 1, 2, 'West', 5, 64, 'Marquette', 'Murray St', 83, 12, 'BE', 'OVC'),
#  (2019, 1, 2, 'West', 6, 91, 'Buffalo', 'Arizona St', 74, 11, 'MAC', 'P12'),
#  (2019, 1, 2, 'West', 7, 61, 'Nevada', 'Florida', 70, 10, 'MWC', 'SEC'),
#  (2019, 1, 2, 'West', 8, 69, 'Syracuse', 'Baylor', 78, 9, 'ACC', 'B12'),
#  (2019, 1, 3, 'South', 1, 71, 'Virginia', 'Gardner Webb', 56, 16, 'ACC', 'BSth'),
#  (2019, 1, 3, 'South', 2, 77, 'Tennessee', 'Colgate', 70, 15, 'SEC', 'Pat'),
#  (2019, 1, 3, 'South', 3, 61, 'Purdue', 'Old Dominion', 48, 14, 'B10', 'CUSA'),
#  (2019, 1, 3, 'South', 4, 64, 'Kansas St', 'UC Irvine', 70, 13, 'B12', 'BW'),
#  (2019, 1, 3, 'South', 5, 54, 'Wisconsin', 'Oregon', 72, 12, 'B10', 'P12'),
#  (2019, 1, 3, 'South', 6, 61, 'Villanova', 'St Marys', 57, 11, 'BE', 'WCC'),
#  (2019, 1, 3, 'South', 7, 72, 'Cincinnati', 'Iowa', 79, 10, 'Amer', 'B10'),
#  (2019, 1, 3, 'South', 8, 72, 'Ole Miss', 'Oklahoma', 95, 9, 'SEC', 'B12'),
#  (2019, 1, 4, 'Midwest', 1, 88, 'North Carolina', 'Iona', 73, 16, 'ACC', 'MAAC'),
#  (2019, 1, 4, 'Midwest', 2, 79, 'Kentucky', 'Abilene Christian', 44, 15, 'SEC', 'Slnd'),
#  (2019, 1, 4, 'Midwest', 3, 84, 'Houston', 'Georgia St', 55, 14, 'Amer', 'SB'),
#  (2019, 1, 4, 'Midwest', 4, 87, 'Kansas', 'Northeastern', 53, 13, 'B12', 'CAA'),
#  (2019, 1, 4, 'Midwest', 5, 78, 'Auburn', 'New Mexico St', 77, 12, 'SEC', 'WAC'),
#  (2019, 1, 4, 'Midwest', 6, 59, 'Iowa St', 'Ohio St', 62, 11, 'B12', 'B10'),
#  (2019, 1, 4, 'Midwest', 7, 84, 'Wofford', 'Seton Hall', 68, 10, 'SC', 'BE'),
#  (2019, 1, 4, 'Midwest', 8, 61, 'Utah St', 'Washington', 78, 9, 'MWC', 'P12'),
#  (2019, 2, 1, 'South', 1, 77, 'Duke', 'Central Florida', 76, 9, 'ACC', 'Amer'),
#  (2019, 2, 1, 'South', 2, 70, 'Michigan St', 'Minnesota', 50, 10, 'B10', 'B10'),
#  (2019, 2, 1, 'South', 3, 69, 'LSU', 'Maryland', 67, 6, 'SEC', 'B10'),
#  (2019, 2, 1, 'South', 4, 67, 'Virginia Tech', 'Liberty', 58, 12, 'ACC', 'BSth'),
#  (2019, 2, 2, 'West', 1, 83, 'Gonzaga', 'Baylor', 71, 9, 'WCC', 'B12'),
#  (2019, 2, 2, 'West', 2, 64, 'Michigan', 'Florida', 49, 10, 'B10', 'SEC'),
#  (2019, 2, 2, 'West', 3, 78, 'Texas Tech', 'Buffalo', 58, 6, 'B12', 'MAC'),
#  (2019, 2, 2, 'West', 4, 90, 'Florida St', 'Murray St', 62, 12, 'ACC', 'OVC'),
#  (2019, 2, 3, 'East', 1, 63, 'Virginia', 'Oklahoma', 51, 9, 'ACC', 'B12'),
#  (2019, 2, 3, 'East', 2, 83, 'Tennessee', 'Iowa', 77, 10, 'SEC', 'B10'),
#  (2019, 2, 3, 'East', 3, 87, 'Purdue', 'Villanova', 61, 6, 'B10', 'BE'),
#  (2019, 2, 3, 'East', 13, 54, 'UC Irvine', 'Oregon', 73, 12, 'BW', 'P12'),
#  (2019, 2, 4, 'Midwest', 1, 81, 'North Carolina', 'Washington', 59, 9, 'ACC', 'P12'),
#  (2019, 2, 4, 'Midwest', 2, 62, 'Kentucky', 'Wofford', 56, 7, 'SEC', 'SC'),
#  (2019, 2, 4, 'Midwest', 3, 74, 'Houston', 'Ohio St', 59, 11, 'Amer', 'B10'),
#  (2019, 2, 4, 'Midwest', 4, 75, 'Kansas', 'Auburn', 89, 5, 'B12', 'SEC'),
#  (2019, 3, 1, 'South', 1, 75, 'Duke', 'Virginia Tech', 73, 4, 'ACC', 'ACC'),
#  (2019, 3, 1, 'South', 2, 80, 'Michigan St', 'LSU', 63, 3, 'B10', 'SEC'),
#  (2019, 3, 2, 'West', 1, 72, 'Gonzaga', 'Florida St', 58, 4, 'WCC', 'ACC'),
#  (2019, 3, 2, 'West', 2, 44, 'Michigan', 'Texas Tech', 63, 3, 'B10', 'B12'),
#  (2019, 3, 3, 'East', 1, 53, 'Virginia', 'Oregon', 49, 12, 'ACC', 'P12'),
#  (2019, 3, 3, 'East', 2, 94, 'Tennessee', 'Purdue', 99, 3, 'SEC', 'B10'),
#  (2019, 3, 4, 'Midwest', 1, 80, 'North Carolina', 'Auburn', 97, 5, 'ACC', 'SEC'),
#  (2019, 3, 4, 'Midwest', 2, 62, 'Kentucky', 'Houston', 58, 3, 'SEC', 'Amer'),
#  (2019, 4, 1, 'South', 1, 67, 'Duke', 'Michigan St', 68, 2, 'ACC', 'B10'),
#  (2019, 4, 2, 'West', 1, 69, 'Gonzaga', 'Texas Tech', 75, 3, 'WCC', 'B12'),
#  (2019, 4, 3, 'East', 1, 80, 'Virginia', 'Purdue', 75, 3, 'ACC', 'B10'),
#  (2019, 4, 4, 'Midwest', 5, 77, 'Auburn', 'Kentucky', 71, 2, 'SEC', 'SEC'),
#  (2019, 5, 1, 'Final Four', 2, 51, 'Michigan St', 'Texas Tech', 61, 3, 'B10', 'B12'),
#  (2019, 5, 2, 'Final Four', 1, 63, 'Virginia', 'Auburn', 62, 5, 'ACC', 'SEC'),
#  (2019, 6, 1, 'Championship', 3, 77, 'Texas Tech', 'Virginia', 85, 1, 'B12', 'ACC'),
#  (2015, 1, 3, 'East', 4, 57, 'Louisville', 'UC Irvine', 55, 13, 'ACC', 'BW')]

# %%
# Create an object of finaldata.
finaldata_obj = engine.execute("SELECT * FROM finaldata").fetchall()

Year = []#BIGINT
Round = []#BIGINT
Region_Number = []#BIGINT
Region_Name = []#TEXT
Home_Seed = []#BIGINT
Home_Score = []#BIGINT
Home_Team = []#TEXT
Away_Team = []#TEXT
Away_Score = []#BIGINT
Away_Seed = []#BIGINT
Home_Conference = []#TEXT
Away_Conference = []#TEXT

# Iterate through finaldata_obj
# Append row/column values to predefined lists
for field in range(len(finaldata_obj)):
    Year.append(finaldata_obj[field][0])
    Round.append(finaldata_obj[field][1])
    Region_Number.append(finaldata_obj[field][2])
    Region_Name.append(finaldata_obj[field][3])
    Home_Seed.append(finaldata_obj[field][4])
    Home_Score.append(finaldata_obj[field][5])
    Home_Team.append(finaldata_obj[field][6])
    Away_Team.append(finaldata_obj[field][7])
    Away_Score.append(finaldata_obj[field][8])
    Away_Seed.append(finaldata_obj[field][9])
    Home_Conference.append(finaldata_obj[field][10])
    Away_Conference.append(finaldata_obj[field][11])

# Create a dataframe that matches the vw_salary_range object
finaldata_df = pd.DataFrame({
    "Year":Year,
    "Round":Round,
    "Region Number":Region_Number,
    "Region Name":Region_Name,
    "Home Seed":Home_Seed,
    "Home Score":Home_Score,
    "Home Team":Home_Team,
    "Away Team":Away_Team,
    "Away Score":Away_Score,
    "Away Seed":Away_Seed,
    "Home Conference":Home_Conference,
    "Away Conference":Away_Conference
})

# View first 5 rows of df
finaldata_df.head()
# Out:
#    Year  Round  Region Number Region Name  Home Seed  Home Score  \
# 0  2015      1              1     Midwest          2          75
# 1  2015      1              1     Midwest          3          69
# 2  2015      1              1     Midwest          5          68
# 3  2015      1              1     Midwest          6          56
# 4  2015      1              1     Midwest          8          66
#
#        Home Team      Away Team  Away Score  Away Seed Home Conference  \
# 0         Kansas  New Mexico St          56         15             B12
# 1     Notre Dame   Northeastern          65         14             ACC
# 2  West Virginia        Buffalo          62         12             B12
# 3         Butler          Texas          48         11              BE
# 4     Cincinnati         Purdue          65          9            Amer
#
#   Away Conference
# 0             WAC
# 1             CAA
# 2             MAC
# 3             B12
# 4             B10
